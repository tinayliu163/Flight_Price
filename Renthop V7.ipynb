# %% [markdown]
# @ author : Ying Liu
#
# # Scrape data from Renthop
#
# # Features:
#
# - Amenities
#
# - price
# - listing_id
# - hopscore
# - street_address
# - neighborhoods
# - expert
# - bedroom
# - bathroom
# - description
# - median_price
# - num_transportation
# - photo
# - No Fee
# - transportation

# %%
import requests
import urllib
from bs4 import BeautifulSoup
import time
import numpy as np
import re
import pandas as pd
import json

# %%
def house_rent(url_link):
    return 'https://www.renthop.com/search/nyc?page=' + url_link

# %%
# return each house's details

def getHouseDetail(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.content, "html.parser")
    
    #Description
    description = soup.find_all("div",{"style":"font-size: 0.90em; line-height: 140%;"})[0].text
    
    #photos
    num_photos = soup.find_all("a",{"data-lightbox" : "listing-photos-set"})
    photo_link = [] 
    for i in range(len(num_photos)):
        photo = num_photos[i]['href']
        photo_link.append(photo) # each house has its own list of photo link
    
    # Amenities
    Amenities = []
    for x in range(len(soup.find_all('td',{'style':'vertical-align: top; padding-left: 8px;'}))):
        amenities_name = soup.find_all('td',{'style':'vertical-align: top; padding-left: 8px;'})[x].text.strip()
        Amenities.append(amenities_name)
    
    #median price
   
    median_price_div = soup.find_all('div',{'style': 'text-align: center; font-size: 1.00em;'})
    if len(median_price_div)>0:
        median_price_info = soup.find_all('div',{'style': 'text-align: center; font-size: 1.00em;'})[0].text.strip()
    else:
        median_price_info = 0
        
    #transportation_name
    trans = []
    for t in range(len(soup.find_all('div',{'class':'subway_nyc'}))):
        subway_name = soup.find_all('div',{'class':'subway_nyc'})[t].text.strip()
        trans.append(subway_name)
        
    #num_transportation
    subway = soup.find_all('div',{'class':'subway_nyc'})
    num_subway = len(subway)

    
    return {"Description":description,"Median_price":median_price_info,"num_transportation": num_subway,"photo_link":photo_link,"Amenities":Amenities,"trans":trans}

# %%
# return house info on each page
price = []
listing_id = []
hopscore = []
street_address = []
neighborhoods = []
expert = []
bedroom = []
bathroom = []
description = []
median_price = []
num_transportation = []
Amenities = []
photo_link = []
trans = []
# latitude = []
# longitude = []

# here is the page 1 to page 200, 4000 samples
for x in range(1,200):
    url_page = house_rent(str(x))
    r_page = requests.get(url_page)
    soup = BeautifulSoup(r_page.content, "html.parser")
    house_data = soup.find_all("div",{"class" : "search-listing"}) #20 house listings
    
    for house in house_data:
        house_id = house.get('listing_id') # each house has its own listing_id
        
        #url for each house
        house_url = house.find_all('a',{'class':'font-size-90 listing-title-link'},href = True)[0]['href']
        house_detail_info = getHouseDetail(house_url) # reture dictionary 
        
        # return values from dict
        # description
        description_info = house_detail_info["Description"]
        description.append(description_info)

        
        # median_price
        
        median_price_info = house_detail_info["Median_price"]
        median_price.append(median_price_info)

        
        Amenities_info = house_detail_info["Amenities"]
        Amenities.append(Amenities_info)
        
        photo_link_info = house_detail_info["photo_link"]
        photo_link.append(photo_link_info)

        
        trans_info = house_detail_info["trans"]
        trans.append(trans_info)
        
        # num_transportation
        subway_info = house_detail_info["num_transportation"]
        num_transportation.append(subway_info)
        
        # price
        price_id = 'listing-{}-price'.format(house_id)
        price_div = house.find_all('div', {'id' : price_id})[0]
        price.append(price_div.text.strip())
        
        # listing_id
        listing_id.append(int(house_id))
        
        # hopscore
        hopscore_id = 'listing-{}-hopscore'.format(house_id)
        hopscore_div = house.find_all('div',{'id': hopscore_id})[0]
        hopscore.append(float(hopscore_div.text.strip()))
        
        # street_address
        title_id = 'listing-{}-title'.format(house_id)
        title_a = house.find_all('a',{'id': title_id})[0]
        title = title_a.text.strip()
        text = 'at'
        address_name = title[title.find(text) + len(text) + 1:]
        street_address.append(address_name)
        
        # bedroom
        title_tag = title_a.text.strip()
        #number = re.findall('\d+', title_tag)
        
        if len(re.findall('BR',title_tag))>0:
            number = title_tag.find('BR')-1
            bedroom.append(title_tag[number])
        else:
            #only one
            bedroom.append(1)
        
        # bathroom
        if len(re.findall('BA',title_tag))>0:
            number = title_tag.find('BA')-1
            bathroom.append(title_tag[number])
        else:
            #only one
            bathroom.append(1)    
        
        #neighborhoods
        neighbor_id = 'listing-{}-neighborhoods'.format(house_id)
        neighbor = house.find_all('div',{'id': neighbor_id})[0].text.strip()
        neighborhoods.append(neighbor)
        
        # address
#         address = [address_name + ',' + neighbor]

        
        # expert
        expert_div = house.find_all('div',{'class':'font-size-80 overflow-clip'})
        if len(expert_div)>0:
            expert.append(expert_div[0].text.strip())
        else:
            expert.append(0)
            
        #latitude & longitude
        
#         for i in neighborhoods: 
#             google_key="AIzaSyBGkYZ7kecirliN_CmzK_n4Nv5T9uH8uog"   
#             google_url = "https://maps.googleapis.com/maps/api/geocode/json?address={}&key={}".format(i,google_key)
#             json_return = requests.get(google_url)
#             json_map_data = json.loads(json_return.text)
#             for js in json_map_data['results']:
#                 lat = js['geometry']['location']['lat']
#                 lng = js['geometry']['location']['lng']
#                 latitude.append(lat)
#                 longitude.append(lng)
        # no fee    
        noFee = []
        for a in Amenities:
            if("No Fee" in a):
                noFee.append(1)
            else:
                noFee.append(0)

# %%
data = {'price': price,'listing_id':listing_id,'hopscore':hopscore,'street_address':street_address,'neighborhoods': neighborhoods,
       'expert': expert,'bedroom':bedroom, 'bathroom':bathroom,'description': description,'median_price':median_price,
       'num_transportation':num_transportation,'photo': photo_link,'Amenities': Amenities,'No Fee':noFee,'transportation':trans,}
#         'latitude':latitude,'longitude':longitude
# There is something wrong with longitude and latitude
Rent_house = pd.DataFrame.from_dict(data = data)
Rent_house
# Out:
#                                             Amenities  No Fee bathroom  \
# 0   [No Fee, Featured, Roof Deck, Dining Room, Doo...       1        2
# 1   [No Fee, Featured, Elevator, Laundry In Buildi...       1        1
# 2   [Featured, Roof Deck, Doorman, Elevator, Laund...       0        1
# 3   [No Fee, Featured, Doorman, Elevator, Pre-War,...       1        2
# 4   [No Fee, Featured, Doorman, Elevator, Pre-War,...       1        2
# 5   [No Fee, Featured, elevator, patio, High Ceili...       1        1
# 6   [Featured, Doorman, Elevator, Pre-War, Dishwas...       0        1
# 7   [No Fee, Featured, Exclusive, Doorman, Elevato...       1        1
# 8   [Featured, Doorman, Elevator, Pre-War, Laundry...       0        1
# 9      [Featured, Balcony, Elevator, Hardwood Floors]       0        1
# 10  [No Fee, Featured, Balcony, Pre-War, Terrace, ...       1        1
# 11  [No Fee, Floorplans Available, Featured, Priva...       1        2
# 12  [No Fee, Featured, Laundry In Unit, Private Ou...       1        3
# 13  [Featured, Exclusive, Elevator, Laundry in Bui...       0        1
# 14  [No Fee, Featured, Parking Space, Cats Allowed...       1        2
# 15  [No Fee, Featured, Parking Space, Cats Allowed...       1        1
# 16  [No Fee, Featured, Parking Space, Cats Allowed...       1        1
# 17  [No Fee, Featured, Parking Space, Cats Allowed...       1        1
# 18  [No Fee, Featured, Parking Space, Cats Allowed...       1        1
# 19  [No Fee, Featured, Parking Space, Cats Allowed...       1        2
# 20  [No Fee, Featured, Parking Space, Cats Allowed...       1        1
# 21  [No Fee, Floorplans Available, Featured, Parki...       1        2
# 22  [No Fee, Featured, Fitness Center, elevator, g...       1        1
# 23  [No Fee, Floorplans Available, Featured, Parki...       1        1
# 24  [No Fee, Featured, Parking Space, Cats Allowed...       1        2
# 25  [No Fee, Featured, Parking Space, Cats Allowed...       1        1
# 26  [No Fee, Featured, Parking Space, Cats Allowed...       1        1
# 27  [No Fee, Featured, Elevator, Laundry in Unit, ...       1        1
# 28  [No Fee, Featured, Parking Space, Cats Allowed...       1        1
# 29  [No Fee, Featured, Parking Space, Cats Allowed...       1        1
# 30  [No Fee, Featured, Private Outdoor Space, Park...       1        2
# 31  [No Fee, Featured, Parking Space, Cats Allowed...       1        1
# 32  [Featured, Exclusive, Cats Allowed, Dogs Allowed]       0        1
# 33  [No Fee, Featured, Parking Space, Cats Allowed...       1        1
# 34  [No Fee, Featured, Parking Space, Cats Allowed...       1        1
# 35  [No Fee, Featured, Cats Allowed, Dogs Allowed,...       1        1
# 36  [No Fee, Featured, Cats Allowed, Dogs Allowed,...       1        1
# 37  [No Fee, Featured, Parking Space, Cats Allowed...       1        1
# 38  [No Fee, Featured, Cats Allowed, Dogs Allowed,...       1        1
# 39  [No Fee, Featured, Cats Allowed, Dogs Allowed,...       1        1
#
#    bedroom                                        description  \
# 0        3  \nAMAZING MURRAY HILL SPACIOUS 2 BEDROOM + 2 B...
# 1        2  \nMASSIVE & FULLY RENOVATED *TRUE* 2 BEDROOM 1...
# 2        1  \n// AMAZING DEAL // LUXURIOUS // MURRAY HILL ...
# 3        1  \nNet Rent advertised. Based on 1 Month Free o...
# 4        1  \nNet Rent advertised. Based on 1 Month Free o...
# 5        3  \n** NO BROKER'S FEE **\n\nThe apartment is in...
# 6        1  \nNet Rent advertised. Based on 1 Month Free o...
# 7        1  \n\n       On the corner of 33rd Street and 1s...
# 8        1  \nNewly renovated studio with hardwood floors ...
# 9        1  \nBEAUTIFUL STUDIO located on the Upper East S...
# 10       3  \nThis is a renovated 3 bedroom apartment with...
# 11       4  \nAmaizing luxury offer!\n\nDon't wait call/te...
# 12       3  \nNO BROKER FEE!!Upper East Side LUXURIOUS bui...
# 13       1  \n\n       6 Charles Street is centrally locat...
# 14       3  \nDONT WAIT TILL IT'S GONE CALL/TXT NOW 347-96...
# 15       1  \nDONT WAIT TILL IT'S GONE CALL/TXT NOW 347-96...
# 16       3  \nDONT WAIT TILL IT'S GONE CALL/TXT NOW 347-96...
# 17       3  \nDONT WAIT TILL IT'S GONE CALL/TXT NOW 347-96...
# 18       2  \nDONT WAIT TILL IT'S GONE CALL/TXT NOW 347-96...
# 19       3  \nDONT WAIT TILL IT'S GONE CALL/TXT NOW 347-96...
# 20       2  \nDONT WAIT TILL IT'S GONE CALL/TXT NOW 347-96...
# 21       4  \nDONT WAIT TILL IT'S GONE CALL/TXT NOW 347-96...
# 22       1  \nMUST SEE ***** HIGH END LUXURY BLDG ***** NO...
# 23       2  \nDONT WAIT TILL IT'S GONE CALL/TXT NOW 347-96...
# 24       3  \nDONT WAIT TILL IT'S GONE CALL/TXT NOW 347-96...
# 25       2  \nDONT WAIT TILL IT'S GONE CALL/TXT NOW 347-96...
# 26       3  \nDONT WAIT TILL IT'S GONE CALL/TXT 347-968-33...
# 27       1  \n**BRILLIANT WEST VILLAGE 1 BEDROOM**APARTMEN...
# 28       2  \nDONT WAIT TILL IT'S GONE CALL/TXT NOW 347-96...
# 29       2  \nDONT WAIT TILL IT'S GONE CALL/TXT NOW 347-96...
# 30       3  \nTo schedule  viewing please Call/Text 347-96...
# 31       3  \nDONT WAIT TILL IT'S GONE CALL/TXT NOW 347-96...
# 32       3  \nNewly renovated 3 bedroom apartment, conveni...
# 33       2  \nDONT WAIT TILL IT'S GONE CALL/TXT NOW 347-96...
# 34       2  \nBuilding and Apartment Amenities\n-Apartment...
# 35       3  \nBuilding and Apartment Amenities\n-Apartment...
# 36       3  \nBuilding and Apartment Amenities\n-Apartment...
# 37       1  \nGigantic 2 & 3 Unfurnished bedrooms RECENTLY...
# 38       1  \nGigantic 2 & 3 Unfurnished bedrooms RECENTLY...
# 39       2  \nBest Deal Downtown!\n\nPlease contact for mo...
#
#                     expert  hopscore  listing_id median_price  \
# 0                        0     100.0     9004417       $4,875
# 1   Upper East Side Expert     100.0     8135722       $3,000
# 2                        0     100.0     9024451       $3,475
# 3                        0     100.0     8821026       $4,150
# 4                        0     100.0     8971416       $4,150
# 5                        0     100.0     8852792       $3,825
# 6                        0     100.0     8971424       $3,850
# 7                        0     100.0     8849569       $3,475
# 8                        0     100.0     8929098       $3,250
# 9                        0     100.0     8881581       $2,100
# 10                       0     100.0     9010700       $4,775
# 11    Gramercy Park Expert     100.0     8744601       $6,675
# 12                       0     100.0     8664922       $9,000
# 13                       0     100.0     9014296       $3,450
# 14                       0     100.0     8300182       $4,500
# 15                       0     100.0     8632223       $3,925
# 16                       0     100.0     8513222       $4,275
# 17                       0     100.0     7116578       $4,075
# 18                       0     100.0     7799174       $3,425
# 19                       0     100.0     8511695       $5,250
# 20    Gramercy Park Expert     100.0     8270208       $3,700
# 21                       0     100.0     8921086       $6,675
# 22                       0     100.0     8921744       $2,275
# 23                       0     100.0     7707428       $3,700
# 24                       0     100.0     8493178       $4,975
# 25                       0     100.0     8006396       $3,500
# 26                       0     100.0     8465103       $4,275
# 27                       0     100.0     8918531       $3,450
# 28                       0     100.0     8398520       $3,200
# 29                       0     100.0     7799172       $3,300
# 30                       0     100.0     8428792       $4,875
# 31                       0     100.0     7428205       $4,750
# 32                       0     100.0     8947262       $3,825
# 33                       0     100.0     8001131       $3,700
# 34    Gramercy Park Expert     100.0     5846640       $3,700
# 35                       0     100.0     8876531       $4,275
# 36                       0     100.0     8887412       $4,275
# 37                       0     100.0     5440278            0
# 38                       0     100.0     3281886            0
# 39                       0     100.0     7347222       $3,500
#
#                                         neighborhoods  num_transportation  \
# 0           Murray Hill, Midtown Manhattan, Manhattan                  21
# 1         Upper East Side, Upper Manhattan, Manhattan                  14
# 2              Kips Bay, Midtown Manhattan, Manhattan                  16
# 3             Koreatown, Midtown Manhattan, Manhattan                  26
# 4             Koreatown, Midtown Manhattan, Manhattan                  26
# 5   East Williamsburg, Williamsburg, Northern Broo...                   9
# 6             Koreatown, Midtown Manhattan, Manhattan                  26
# 7              Kips Bay, Midtown Manhattan, Manhattan                  20
# 8   Brooklyn Heights, Northwestern Brooklyn, Brooklyn                  20
# 9   Yorkville, Upper East Side, Upper Manhattan, M...                   4
# 10        East Village, Downtown Manhattan, Manhattan                  10
# 11        Gramercy Park, Midtown Manhattan, Manhattan                  17
# 12  Yorkville, Upper East Side, Upper Manhattan, M...                   4
# 13        West Village, Downtown Manhattan, Manhattan                  25
# 14     Garment District, Midtown Manhattan, Manhattan                  21
# 15        Gramercy Park, Midtown Manhattan, Manhattan                  17
# 16        Gramercy Park, Midtown Manhattan, Manhattan                  17
# 17        East Village, Downtown Manhattan, Manhattan                  12
# 18     Garment District, Midtown Manhattan, Manhattan                  21
# 19        Gramercy Park, Midtown Manhattan, Manhattan                  17
# 20        Gramercy Park, Midtown Manhattan, Manhattan                  17
# 21        Gramercy Park, Midtown Manhattan, Manhattan                  17
# 22          Crown Heights, Central Brooklyn, Brooklyn                  12
# 23        Gramercy Park, Midtown Manhattan, Manhattan                  17
# 24  Yorkville, Upper East Side, Upper Manhattan, M...                   4
# 25        East Village, Downtown Manhattan, Manhattan                  12
# 26        Gramercy Park, Midtown Manhattan, Manhattan                  17
# 27        West Village, Downtown Manhattan, Manhattan                  20
# 28  Yorkville, Upper East Side, Upper Manhattan, M...                   7
# 29          Murray Hill, Midtown Manhattan, Manhattan                  20
# 30          Murray Hill, Midtown Manhattan, Manhattan                  20
# 31          Murray Hill, Midtown Manhattan, Manhattan                  17
# 32  East Williamsburg, Williamsburg, Northern Broo...                   9
# 33        Gramercy Park, Midtown Manhattan, Manhattan                  17
# 34        Gramercy Park, Midtown Manhattan, Manhattan                  17
# 35        Gramercy Park, Midtown Manhattan, Manhattan                  17
# 36        Gramercy Park, Midtown Manhattan, Manhattan                  17
# 37        East Village, Downtown Manhattan, Manhattan                  12
# 38        Gramercy Park, Midtown Manhattan, Manhattan                  17
# 39        East Village, Downtown Manhattan, Manhattan                  12
#
#                                                 photo   price  \
# 0   [https://photos.renthop.com/7/9004417_47637c17...  $4,800
# 1   [https://photos.renthop.com/7/7581252_49dfa883...  $3,425
# 2   [https://photos.renthop.com/7/9024451_66efbbb8...  $3,200
# 3   [https://photos.renthop.com/7/8821026_22d59d29...  $4,426
# 4   [https://photos.renthop.com/7/8971416_f538953c...  $4,315
# 5   [https://photos.renthop.com/7/8852792_3f5676ce...  $3,590
# 6   [https://photos.renthop.com/7/8971424_94586bba...  $3,369
# 7   [https://photos.renthop.com/7/8849569_b0ded64b...  $4,000
# 8   [https://photos.renthop.com/7/8929098_2c7c3705...  $2,675
# 9   [https://photos.renthop.com/7/8881581_525cd4fc...  $2,150
# 10  [https://photos.renthop.com/7/9010700_a45ac1fd...  $5,395
# 11  [https://photos.renthop.com/7/8744601_eba8156b...  $6,400
# 12  [https://photos.renthop.com/7/8664922_75115122...  $6,000
# 13  [https://photos.renthop.com/7/9014296_ee6986c7...  $3,950
# 14  [https://photos.renthop.com/7/8300182_33077260...  $4,600
# 15  [https://photos.renthop.com/7/8632223_af26ad51...  $3,000
# 16  [https://photos.renthop.com/7/8513222_cc3fe591...  $4,000
# 17  [https://photos.renthop.com/7/7116578_ad5d81fc...  $3,900
# 18  [https://photos.renthop.com/7/3813254_e2d02427...  $3,200
# 19  [https://photos.renthop.com/7/8511695_43460a69...  $4,100
# 20  [https://photos.renthop.com/7/8270208_3681005b...  $3,095
# 21  [https://photos.renthop.com/7/8921086_91645171...  $5,000
# 22  [https://photos.renthop.com/7/8921744_bce06db6...  $3,000
# 23  [https://photos.renthop.com/7/6233109_230c3245...  $3,200
# 24  [https://photos.renthop.com/7/8493178_5742527b...  $3,900
# 25  [https://photos.renthop.com/7/8006396_23abc682...  $3,000
# 26  [https://photos.renthop.com/7/8465103_fc50c7d4...  $3,200
# 27  [https://photos.renthop.com/7/8918531_e5a99e88...  $4,100
# 28  [https://photos.renthop.com/7/8398520_c17a8406...  $3,000
# 29  [https://photos.renthop.com/7/3697905_d86afbf3...  $3,200
# 30  [https://photos.renthop.com/7/314de5264c94b79c...  $4,000
# 31  [https://photos.renthop.com/7/7428205_57bfb20b...  $3,300
# 32  [https://photos.renthop.com/7/7968792_f2bc1ed0...  $2,950
# 33  [https://photos.renthop.com/7/8001131_95482b3b...  $3,000
# 34  [https://photos.renthop.com/7/5846640_cc69802e...  $3,100
# 35  [https://photos.renthop.com/7/8876531_bb716dff...  $4,000
# 36  [https://photos.renthop.com/7/8887412_e831a11a...  $3,300
# 37  [https://photos.renthop.com/7/5440278_6e42372c...  $1,400
# 38  [https://photos.renthop.com/7/3281886_b092152f...  $1,400
# 39  [https://photos.renthop.com/7/7347222_f3c076b2...  $3,100
#
#                    street_address  \
# 0                East 39th Street
# 1                   East 78th ESt
# 2                East 29th Street
# 3             50 West 34th Street
# 4             50 West 34th Street
# 5        679 Grand Street, Apt 4B
# 6             50 West 34th Street
# 7   377 East 33rd Street, Apt 21E
# 8                    Clark Street
# 9                East 84th Street
# 10                  343 E 5th St.
# 11                     Eaast 20's
# 12                Upper East Side
# 13           6 Charles St, Apt 2D
# 14                      west 30's
# 15                      East 20's
# 16                      East 20's
# 17                      east 10's
# 18                      West 30's
# 19                      East 20's
# 20                      East 20's
# 21                      east 20's
# 22   608 Franklin Avenue, Apt 409
# 23               East 20's street
# 24                      east 90's
# 25                      east 10's
# 26                      East 20's
# 27                 Charles Street
# 28                  east 90's/3av
# 29        33 street by 5th avenue
# 30               East 30's Street
# 31               east 33st by 5av
# 32       402 Grand Street, Apt 1A
# 33             800sf at east 20's
# 34                       East 20s
# 35                      East 20's
# 36                      East 20's
# 37               East 14th street
# 38               East 20th street
# 39               East 14th street
#
#                                        transportation
# 0   [4, 5, 6, 7, S, 6, B, D, F, M, 7, E, 6, M, N, ...
# 1          [N, Q, T, 6, 4, 5, 6, F, 4, 5, 6, N, Q, R]
# 2    [6, N, R, 4, 5, 6, 7, S, L, 4, 5, 6, N, Q, R, L]
# 3   [N, Q, R, B, D, F, M, N, R, 6, B, D, F, M, 7, ...
# 4   [N, Q, R, B, D, F, M, N, R, 6, B, D, F, M, 7, ...
# 5                         [L, G, L, G, M, J, M, J, Z]
# 6   [N, Q, R, B, D, F, M, N, R, 6, B, D, F, M, 7, ...
# 7   [6, 4, 5, 6, 7, S, N, R, B, D, F, M, 7, N, Q, ...
# 8   [2, 3, 2, 3, A, C, 4, 5, J, Z, 2, 3, 4, 5, R, ...
# 9                                        [N, Q, T, 6]
# 10                     [F, 6, 6, B, D, F, M, N, R, L]
# 11  [6, L, 4, 5, 6, N, Q, R, L, N, R, 1, 2, 3, F, ...
# 12                                       [N, Q, T, 6]
# 13  [1, A, C, E, B, D, F, M, 1, 2, 3, F, M, L, A, ...
# 14  [A, C, E, 1, 2, 3, A, C, E, N, Q, R, 7, S, 1, ...
# 15  [6, L, 4, 5, 6, N, Q, R, L, N, R, 1, 2, 3, F, ...
# 16  [6, L, 4, 5, 6, N, Q, R, L, N, R, 1, 2, 3, F, ...
# 17               [L, 6, 4, 5, 6, N, Q, R, L, N, R, F]
# 18  [A, C, E, 1, 2, 3, A, C, E, N, Q, R, 7, S, 7, ...
# 19  [6, L, 4, 5, 6, N, Q, R, L, N, R, 1, 2, 3, F, ...
# 20  [6, L, 4, 5, 6, N, Q, R, L, N, R, 1, 2, 3, F, ...
# 21  [6, L, 4, 5, 6, N, Q, R, L, N, R, 1, 2, 3, F, ...
# 22               [S, A, S, A, C, 2, 3, 4, 5, S, 2, 3]
# 23  [6, L, 4, 5, 6, N, Q, R, L, N, R, 1, 2, 3, F, ...
# 24                                       [N, Q, T, 6]
# 25               [L, 6, 4, 5, 6, N, Q, R, L, N, R, F]
# 26  [6, L, 4, 5, 6, N, Q, R, L, N, R, 1, 2, 3, F, ...
# 27  [1, A, C, E, B, D, F, M, A, C, E, L, 1, 2, 3, ...
# 28                              [6, 4, 5, 6, N, Q, T]
# 29  [6, N, Q, R, B, D, F, M, N, R, B, D, F, M, 7, ...
# 30  [6, 4, 5, 6, 7, S, B, D, F, M, 7, N, Q, R, B, ...
# 31  [6, N, R, N, Q, R, B, D, F, M, F, M, 4, 5, 6, ...
# 32                        [G, L, M, J, Z, M, J, L, G]
# 33  [6, L, 4, 5, 6, N, Q, R, L, N, R, 1, 2, 3, F, ...
# 34  [L, 6, 4, 5, 6, N, Q, R, L, N, R, 1, 2, 3, F, ...
# 35  [6, L, 4, 5, 6, N, Q, R, L, N, R, 1, 2, 3, F, ...
# 36  [L, 6, 4, 5, 6, N, Q, R, L, N, R, 1, 2, 3, F, ...
# 37               [L, 6, 4, 5, 6, N, Q, R, L, N, R, F]
# 38  [L, 6, 4, 5, 6, N, Q, R, L, N, R, 1, 2, 3, F, ...
# 39               [L, 4, 5, 6, N, Q, R, L, 6, N, R, F]

# %%
Rent_house.to_csv('/Users/admin/Documents/renthop_house.csv')
